# %% [markdown]
# ### Import the necessary libraries.

# %%
import numpy as np
import pandas as pd

# %%
#from google.colab import files
#files.upload()

# %% [markdown]
# ### Import the first dataset cars1 and cars2 and assign each to a variable called cars1 and cars2

# %%
cars1=pd.read_csv("cars1.csv")
cars2=pd.read_csv("cars2.csv")

# %%
cars1.head()
# Out:
#    Unnamed: 0   mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0           0  18.0          8           307        130    3504          12.0
# 1           1  15.0          8           350        165    3693          11.5
# 2           2  18.0          8           318        150    3436          11.0
# 3           3  16.0          8           304        150    3433          12.0
# 4           4  17.0          8           302        140    3449          10.5
#
#    model  origin                        car  Unnamed: 9  Unnamed: 10  \
# 0     70       1  chevrolet chevelle malibu         NaN          NaN
# 1     70       1          buick skylark 320         NaN          NaN
# 2     70       1         plymouth satellite         NaN          NaN
# 3     70       1              amc rebel sst         NaN          NaN
# 4     70       1                ford torino         NaN          NaN
#
#    Unnamed: 11  Unnamed: 12  Unnamed: 13
# ...

# %%
cars2.head()
# Out:
#    Unnamed: 0   mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0           0  33.0          4            91         53    1795          17.4
# 1           1  20.0          6           225        100    3651          17.7
# 2           2  18.0          6           250         78    3574          21.0
# 3           3  18.5          6           250        110    3645          16.2
# 4           4  17.5          6           258         95    3193          17.8
#
#    model  origin                 car
# 0     76       3         honda civic
# 1     76       1      dodge aspen se
# 2     76       1   ford granada ghia
# 3     76       1  pontiac ventura sj
# 4     76       1       amc pacer d/l

# %% [markdown]
# ### Oops, it seems our first dataset has some unnamed blank columns, fix cars1.

# %%
cars1=cars1.loc[:,'mpg':'car']
cars2=cars2.loc[:,'mpg':'car']

# %%
cars1.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0  18.0          8           307        130    3504          12.0     70
# 1  15.0          8           350        165    3693          11.5     70
# 2  18.0          8           318        150    3436          11.0     70
# 3  16.0          8           304        150    3433          12.0     70
# 4  17.0          8           302        140    3449          10.5     70
#
#    origin                        car
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %% [markdown]
# ### What is the number of observations in each dataset?

# %%
cars1.count()
# Out:
# mpg             198
# cylinders       198
# displacement    198
# horsepower      198
# weight          198
# acceleration    198
# model           198
# origin          198
# car             198
# dtype: int64

# %%
cars2.count()
# Out:
# mpg             200
# cylinders       200
# displacement    200
# horsepower      200
# weight          200
# acceleration    200
# model           200
# origin          200
# car             200
# dtype: int64

# %% [markdown]
# ### Join cars1 and cars2 into a single DataFrame called cars.

# %%
cars=cars1.append(cars2,sort=True)

# %%
cars.head()
# Out:
#    acceleration                        car  cylinders  displacement  \
# 0          12.0  chevrolet chevelle malibu          8           307
# 1          11.5          buick skylark 320          8           350
# 2          11.0         plymouth satellite          8           318
# 3          12.0              amc rebel sst          8           304
# 4          10.5                ford torino          8           302
#
#   horsepower  model   mpg  origin  weight
# 0        130     70  18.0       1    3504
# 1        165     70  15.0       1    3693
# 2        150     70  18.0       1    3436
# 3        150     70  16.0       1    3433
# 4        140     70  17.0       1    3449

# %% [markdown]
# ### Oops, there is a column missing, called owners. Create a random number Series from 15,000 to 73,000. Then, add the column owners to cars.

# %%
a=[]
for j in range(0,398):
    a.append(np.random.randint(15000,73000))

# %%
#cars=cars.assign(Owners=a)
a
# Out:
# [38219,
#  70043,
#  36842,
#  66590,
#  68498,
#  20593,
#  36715,
#  54001,
#  60887,
#  23495,
#  28943,
#  34384,
#  37398,
#  23904,
#  21608,
#  69358,
#  46011,
#  49961,
#  24447,
#  31024,
#  46719,
#  60784,
#  43339,
#  43304,
#  36264,
#  17354,
#  36462,
#  39054,
#  47221,
#  47891,
#  33742,
#  23433,
#  72080,
#  22350,
#  43817,
#  57117,
#  68596,
#  58736,
#  25050,
#  54180,
#  66109,
#  47107,
#  23108,
#  57206,
#  21613,
#  19342,
#  56101,
#  38036,
#  63404,
#  32207,
#  21595,
#  66736,
#  42353,
#  54778,
#  70991,
#  30844,
#  34020,
#  48166,
#  46841,
#  48162,
#  27305,
#  52987,
#  36052,
#  17509,
#  52704,
#  43620,
#  47465,
#  36427,
#  64846,
#  40562,
#  43675,
#  49854,
#  24036,
#  38479,
#  69123,
#  21867,
#  17621,
#  20256,
#  18184,
#  43465,
#  62996,
#  59488,
#  42252,
#  49729,
#  20254,
#  16773,
#  32796,
#  38624,
#  16274,
#  40074,
#  29882,
#  72320,
#  38766,
#  71589,
#  42277,
#  54570,
#  44623,
#  33624,
#  16029,
#  60436,
# ...

# %%
cars.head()
# Out:
#    acceleration                        car  cylinders  displacement  \
# 0          12.0  chevrolet chevelle malibu          8           307
# 1          11.5          buick skylark 320          8           350
# 2          11.0         plymouth satellite          8           318
# 3          12.0              amc rebel sst          8           304
# 4          10.5                ford torino          8           302
#
#   horsepower  model   mpg  origin  weight
# 0        130     70  18.0       1    3504
# 1        165     70  15.0       1    3693
# 2        150     70  18.0       1    3436
# 3        150     70  16.0       1    3433
# 4        140     70  17.0       1    3449
